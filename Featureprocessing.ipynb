# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df = pd.read_csv(r'C:\Users\jayak\OneDrive\Desktop\Data Analytics\Featurepro2.csv')

# %%
df.head()
# Out:
#    Age  Height  Weight  Blood_Pressure  Cholesterol  Glucose  \
# 0   25     175      70             120          180       90
# 1   32     160      65             130          200       95
# 2   45     180      80             140          220      100
# 3   37     165      72             125          185       92
# 4   29     170      68             118          175       88
#
#    Hours_of_Exercise_per_Week  Gender Smoking_Status Occupation  Output
# 0                           5    Male     Non-Smoker   Engineer       1
# 1                           3  Female         Smoker     Doctor       2
# 2                           1   Other  Former Smoker    Teacher       1
# 3                           4  Female     Non-Smoker   Engineer       3
# 4                           6    Male     Non-Smoker     Doctor       1

# %%
df.info
# Out:
# <bound method DataFrame.info of     Age  Height  Weight  Blood_Pressure  Cholesterol  Glucose  \
# 0    25     175      70             120          180       90
# 1    32     160      65             130          200       95
# 2    45     180      80             140          220      100
# 3    37     165      72             125          185       92
# 4    29     170      68             118          175       88
# 5    50     155      75             135          210       98
# 6    41     172      77             130          205       96
# 7    28     168      67             115          170       85
# 8    34     177      73             122          182       91
# 9    42     160      79             138          215       99
# 10   30     178      76             120          190       93
# 11   36     162      70             127          188       94
# 12   27     175      68             119          179       87
# 13   39     170      78             135          210       97
# ...

# %%
df_dummies = pd.get_dummies(df)

# %%
df_dummies.info
# Out:
# <bound method DataFrame.info of     Age  Height  Weight  Blood_Pressure  Cholesterol  Glucose  \
# 0    25     175      70             120          180       90
# 1    32     160      65             130          200       95
# 2    45     180      80             140          220      100
# 3    37     165      72             125          185       92
# 4    29     170      68             118          175       88
# 5    50     155      75             135          210       98
# 6    41     172      77             130          205       96
# 7    28     168      67             115          170       85
# 8    34     177      73             122          182       91
# 9    42     160      79             138          215       99
# 10   30     178      76             120          190       93
# 11   36     162      70             127          188       94
# 12   27     175      68             119          179       87
# 13   39     170      78             135          210       97
# ...

# %%
df_dummies.head()
# Out:
#    Age  Height  Weight  Blood_Pressure  Cholesterol  Glucose  \
# 0   25     175      70             120          180       90
# 1   32     160      65             130          200       95
# 2   45     180      80             140          220      100
# 3   37     165      72             125          185       92
# 4   29     170      68             118          175       88
#
#    Hours_of_Exercise_per_Week  Output  Gender_Female  Gender_Male  \
# 0                           5       1          False         True
# 1                           3       2           True        False
# 2                           1       1          False        False
# 3                           4       3           True        False
# 4                           6       1          False         True
#
#    Gender_Other  Smoking_Status_Former Smoker  Smoking_Status_Non-Smoker  \
# 0         False                         False                       True
# ...

# %%
# By doing this we can face problems llike:
# -losing important information
# - The size of the data set will drastically increase

# %%
# to solve above we can use LabelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
le.fit_transform(['Male','Female','Other'])
# Out:
# array([1, 0, 2], dtype=int64)

# %%
df['Gender']= df['Gender'].map({'Male':0,
                                'Female':1,
                                'Other':2})

# %%
df.head()
# We can do same thing for other features also
# Out:
#    Age  Height  Weight  Blood_Pressure  Cholesterol  Glucose  \
# 0   25     175      70             120          180       90
# 1   32     160      65             130          200       95
# 2   45     180      80             140          220      100
# 3   37     165      72             125          185       92
# 4   29     170      68             118          175       88
#
#    Hours_of_Exercise_per_Week  Gender Smoking_Status Occupation  Output
# 0                           5       0     Non-Smoker   Engineer       1
# 1                           3       1         Smoker     Doctor       2
# 2                           1       2  Former Smoker    Teacher       1
# 3                           4       1     Non-Smoker   Engineer       3
# 4                           6       0     Non-Smoker     Doctor       1

# %%
# this is also no so ideal in real life data sets, there may be more than 500 categories in a feature. So we can use a method called cosmbining Sparse class.
