# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\jayak\OneDrive\Desktop\Data Analytics\unibimul3.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of      Study_Hours  Test_Score  Attendance  Age  GPA  Hours_Slept  Passed
# 0             35          88          90   20  3.5            7       1
# 1             25          78          80   21  3.0            6       1
# 2             45          92          95   22  3.8            8       1
# 3             30          75          85   23  2.8            6       0
# 4             20          65          70   24  2.5            5       0
# ..           ...         ...         ...  ...  ...          ...     ...
# 96            45          91          93   22  3.8            8       1
# 97            20          63          69   25  2.1            5       0
# 98            50          96          98   22  4.0            8       1
# 99            40          84          90   23  3.6            7       1
# 100           15          54          60   25  2.0            5       0
#
# [101 rows x 7 columns]>

# %%
df1 = df.loc[df['Passed'] == 1]
df0 = df.loc[df['Passed'] == 0]

# %%
df1.info
# Out:
# <bound method DataFrame.info of     Study_Hours  Test_Score  Attendance  Age  GPA  Hours_Slept  Passed
# 0            35          88          90   20  3.5            7       1
# 1            25          78          80   21  3.0            6       1
# 2            45          92          95   22  3.8            8       1
# 5            50          95          98   22  4.0            7       1
# 6            40          85          90   23  3.6            7       1
# 9            48          94          97   22  3.9            8       1
# 10           37          80          85   21  3.2            6       1
# 12           38          83          88   22  3.4            7       1
# 13           32          77          82   23  3.1            6       1
# 15           44          89          92   21  3.7            7       1
# 17           33          79          84   22  3.3            6       1
# 19           41          87          91   23  3.5            7       1
# ...

# %%
plt.plot((df1['Passed']),np.zeros_like(df1['Passed']), 'o')

# %%
sns.FacetGrid(df,hue= 'Passed').map(plt.scatter,'Study_Hours','Attendance').add_legend()

# %%
sns.pairplot(df,hue='Passed')
